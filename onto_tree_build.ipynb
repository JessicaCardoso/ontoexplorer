# %% [markdown]
# ## Carregar bibliotecas utilizadas na construção da ontology_tree

# %%
from copy import deepcopy
import pickle
import os
import sys

from SPARQLWrapper import SPARQLWrapper, JSON
from ontotrees import OntologyTrees

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
ignore_properties = [
    "http://dbpedia.org/ontology/birthName",
    "http://www.movieontology.org/2009/11/09/movieontology.owl#companyName",
    "http://www.movieontology.org/2009/10/01/movieontology.owl#title"
]

# %% [markdown]
# ### Filtrar nós inválidos
# Funções para remover nós de propriedades que não retornem resultados na Ontologia
#
# Para realizar essa operação é necessária a criação de um arquivo .env com as crendenciais:
#
# - Credenciais do _endpoint SPARQL_ em um arquivo _.env_, contendo:
#     - **DB_ENDPOINT**: Endreço do endpoint SPARQL
#     - **LOGIN**: Usuário de acesso ao banco de triplas
#     - **PASSWORD**: Senha de acesso ao banco de triplas

# %%
def check_property(sparql_wrapper, prop_uri):
    if prop_uri in ignore_properties:
        return False
    sparql_query = f"""
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    ASK
    WHERE {{
    # ?a <{prop_uri}> ?b.
    }}
    """
    sparql_wrapper.setQuery(sparql_query)
    sparql_wrapper.setReturnFormat(JSON)
    results = sparql_wrapper.query().convert()
    return results["boolean"]


def get_valid_node(sparql_wrapper, key, tree):
    if tree[key].is_leaf:
        if check_property(sparql_wrapper, tree[key].data):
            return tree[key]
        else:
            return None
    else:
        node = deepcopy(tree[key])
        node.children = []
        for child_key in tree[key].children:
            child = get_valid_node(sparql_wrapper, child_key, tree)
            if child:
                node.add_child(child.data)

        if node.children:
            return node
        else:
            return None


def adjust_properties_tree(sparql_wrapper, properties):
    filtered_tree = dict()
    for key, _ in properties.items():
        valid_node = get_valid_node(sparql_wrapper, key, properties)
        if valid_node:
            filtered_tree[key] = valid_node
    return filtered_tree


def remove_nodes_without_results(ontology_tree, filename="ontology_trees.pkl"):
    sparql_wrapper = SPARQLWrapper(os.getenv("DB_ENDPOINT"))
    sparql_wrapper.setCredentials(os.getenv("LOGIN"), os.getenv("PASSWORD"))

    object_prop_tree = adjust_properties_tree(
        sparql_wrapper, ontology_tree.get_tree("object_properties")
    )
    data_prop_tree = adjust_properties_tree(
        sparql_wrapper, ontology_tree.get_tree("data_properties")
    )

    ontology_tree.replace_tree("object_properties", object_prop_tree)
    ontology_tree.replace_tree("data_properties", data_prop_tree)

    with open(filename, "wb") as output:
        print(f"Saving as {filename}")
        pickle.dump(ontology_tree, output, pickle.HIGHEST_PROTOCOL)

# %%
# Carregar arquivo de ontologia como uma OntologyTrees
onto_trees = OntologyTrees(lang="pt-br")
onto_trees.load_ontology("movieontology.ttl", format="ttl")

# Nome das árvores geradas
print(onto_trees.trees_names)

# Profundidade máxima de cada árvore
for tree_name in onto_trees.trees_names:
    print(onto_trees.get_max_depth(tree_name, onto_trees.get_root(tree_name)))
        
# with open("ontology_trees.pkl", "wb") as output:
#     pickle.dump(ontology_tree, output, pickle.HIGHEST_PROTOCOL)
# Out:
# ['classes', 'object_properties', 'data_properties']
# 6
# 3
# 2

# %% [markdown]
# > Necessário o arquivo .env contendo as crendenciais do banco, para executar a próxima célula, após colocar as crendenciais carregue-as no ambiente com load_dotenv()

# %%
remove_nodes_without_results(onto_trees, "ontology_trees.pkl")
# Out:
# Saving as ontology_trees.pkl

# %%
import pickle


onto_trees = pickle.load(open("ontology_trees.pkl", "rb"))

# %%
trees = onto_trees.trees

# %%
def _get_entities(question_triples):
    question_triples.sort(key=lambda x: x[1])
    entities = dict()
    subj_ref = {}
    prop_ref = {}
    for subj, pred, obj in question_triples:
        if pred == "has_value":
            entities[subj] = False
            if obj in trees["classes"]:
                entities[obj] = True
                if subj in subj_ref:
                    subj_ref[subj].append(obj)
                else:
                    subj_ref[subj] = [obj]
            else:
                entities[obj] = False
        else:
            if obj in subj_ref:
                for value in subj_ref[obj]:
                    prop_ref[value] = pred
            # Subject
            if subj not in entities:
                entities[subj] = True
            # Object
            if obj not in entities:
                entities[obj] = True
            # Predicate
            if entities[obj]:
                entities[pred] = True
            else:
                entities[pred] = False
    return prop_ref, entities

# %%
trees["classes"]
# Out:
# {'http://www.movieontology.org/2009/10/01/movieontology.owl#TV-Entertainment': <ontotrees.node.Node at 0x7f2e98679a90>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Experience': <ontotrees.node.Node at 0x7f2e984dc1d0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Imaginational_Entertainment': <ontotrees.node.Node at 0x7f2e984dc208>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Entertainment': <ontotrees.node.Node at 0x7f2e984dc240>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#North_American_Company': <ontotrees.node.Node at 0x7f2e984dc278>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Location_Company': <ontotrees.node.Node at 0x7f2e984dc2b0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Sound_Mix': <ontotrees.node.Node at 0x7f2e984dc2e8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Presentation': <ontotrees.node.Node at 0x7f2e984dc320>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Certification': <ontotrees.node.Node at 0x7f2e984dc358>,
#  'http://www.w3.org/2002/07/owl#Thing': <ontotrees.node.Node at 0x7f2e984dc390>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Heavy_Sensible': <ontotrees.node.Node at 0x7f2e984dc3c8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Sensible': <ontotrees.node.Node at 0x7f2e984dc400>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Actionreach': <ontotrees.node.Node at 0x7f2e984dc438>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Caribbean': <ontotrees.node.Node at 0x7f2e984dc470>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#America': <ontotrees.node.Node at 0x7f2e984dc4a8>,
#  'http://dbpedia.org/ontology/Actor': <ontotrees.node.Node at 0x7f2e984dc4e0>,
#  'http://dbpedia.org/ontology/Person': <ontotrees.node.Node at 0x7f2e984dc550>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Special-Info': <ontotrees.node.Node at 0x7f2e984dc5c0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Information': <ontotrees.node.Node at 0x7f2e984dc5f8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Movie': <ontotrees.node.Node at 0x7f2e984dc630>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Southern_Africa': <ontotrees.node.Node at 0x7f2e984dc6a0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Africa': <ontotrees.node.Node at 0x7f2e984dc6d8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Eastern_Europe': <ontotrees.node.Node at 0x7f2e984dc748>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Europe': <ontotrees.node.Node at 0x7f2e984dc780>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Australia_and_New_Zealand': <ontotrees.node.Node at 0x7f2e984dc828>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Oceania': <ontotrees.node.Node at 0x7f2e984dc860>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Fun': <ontotrees.node.Node at 0x7f2e984dc8d0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#SocialActive': <ontotrees.node.Node at 0x7f2e984dc908>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Logical_Thrilling': <ontotrees.node.Node at 0x7f2e984dc940>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Thrilling': <ontotrees.node.Node at 0x7f2e984dc978>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Kids': <ontotrees.node.Node at 0x7f2e984dc9b0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Costume_Designer': <ontotrees.node.Node at 0x7f2e984dc9e8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#North_European_Company': <ontotrees.node.Node at 0x7f2e984dca20>,
#  'http://dbpedia.org/page/Film_Director': <ontotrees.node.Node at 0x7f2e984dca58>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Northern_Africa': <ontotrees.node.Node at 0x7f2e984dcac8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Melanesia': <ontotrees.node.Node at 0x7f2e984dcb00>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Documentarial_Information': <ontotrees.node.Node at 0x7f2e984dcb38>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Entertaining_Information': <ontotrees.node.Node at 0x7f2e984dcb70>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Historical_Information': <ontotrees.node.Node at 0x7f2e984dcba8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Online_retailer': <ontotrees.node.Node at 0x7f2e984dcbe0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Genre': <ontotrees.node.Node at 0x7f2e984dcc18>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Musical_Entertainment': <ontotrees.node.Node at 0x7f2e984dcc50>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Intelectual_Entertainment': <ontotrees.node.Node at 0x7f2e984dcc88>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Territory': <ontotrees.node.Node at 0x7f2e984dccc0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Middle_Africa': <ontotrees.node.Node at 0x7f2e984dccf8>,
#  'http://www.daslab.inf.puc-rio.br/ontologies/RelationshipNotes#Relationship': <ontotrees.node.Node at 0x7f2e984dcd30>,
#  'None': <ontotrees.node.Node at 0x7f2e984dcda0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Colorinfo': <ontotrees.node.Node at 0x7f2e984dcdd8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Fast-Info': <ontotrees.node.Node at 0x7f2e984dce10>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Western_Europe': <ontotrees.node.Node at 0x7f2e984dce48>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Love': <ontotrees.node.Node at 0x7f2e984dce80>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Western_Africa': <ontotrees.node.Node at 0x7f2e984dcef0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Asia': <ontotrees.node.Node at 0x7f2e984dcf28>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#SciFi_and_Fantasy': <ontotrees.node.Node at 0x7f2e984dcf60>,
#  'http://www.movieontology.org/2009/11/09/movieontology.owl#Consumable_Product': <ontotrees.node.Node at 0x7f2e984dcf98>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Old_Action': <ontotrees.node.Node at 0x7f2e984dcfd0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Eastern_Africa': <ontotrees.node.Node at 0x7f2e98472048>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Award': <ontotrees.node.Node at 0x7f2e98472080>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Southern_Europe': <ontotrees.node.Node at 0x7f2e984720b8>,
#  'http://dbpedia.org/ontology/CompanyCountry': <ontotrees.node.Node at 0x7f2e984720f0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#TVSeries': <ontotrees.node.Node at 0x7f2e98472128>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#South_American_Company': <ontotrees.node.Node at 0x7f2e98472160>,
#  'http://dbpedia.org/ontology/Musical_Artist': <ontotrees.node.Node at 0x7f2e98472198>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Producer': <ontotrees.node.Node at 0x7f2e984721d0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Micronesia': <ontotrees.node.Node at 0x7f2e98472208>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Oceanian_Company': <ontotrees.node.Node at 0x7f2e98472240>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Brute_Action': <ontotrees.node.Node at 0x7f2e98472278>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Northern_America': <ontotrees.node.Node at 0x7f2e984722b0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Production_Company': <ontotrees.node.Node at 0x7f2e984722e8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Porn': <ontotrees.node.Node at 0x7f2e98472320>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Southeastern_Asia': <ontotrees.node.Node at 0x7f2e98472358>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#LatinAmerica': <ontotrees.node.Node at 0x7f2e98472390>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Northern_Europe': <ontotrees.node.Node at 0x7f2e984723c8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#South_America': <ontotrees.node.Node at 0x7f2e98472400>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Editor': <ontotrees.node.Node at 0x7f2e98472438>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#SouthEast_Asian_Company': <ontotrees.node.Node at 0x7f2e984724a8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Central_Asia': <ontotrees.node.Node at 0x7f2e984724e0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#West_European_Company': <ontotrees.node.Node at 0x7f2e98472518>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Eastern_Asia': <ontotrees.node.Node at 0x7f2e98472550>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Southern_Asia': <ontotrees.node.Node at 0x7f2e98472588>,
#  'http://dbpedia.org/ontology/Language': <ontotrees.node.Node at 0x7f2e984725c0>,
#  'http://www.movieontology.org/2009/11/09/movieontology.owl#Actress': <ontotrees.node.Node at 0x7f2e984725f8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#East_Asian_Company': <ontotrees.node.Node at 0x7f2e98472668>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#South_European_Company': <ontotrees.node.Node at 0x7f2e984726a0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Polynesia': <ontotrees.node.Node at 0x7f2e984726d8>,
#  'http://dbpedia.org/page/Place': <ontotrees.node.Node at 0x7f2e98472710>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Sensible_Thrilling': <ontotrees.node.Node at 0x7f2e98472780>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Info-TV': <ontotrees.node.Node at 0x7f2e984727b8>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Central_America': <ontotrees.node.Node at 0x7f2e984727f0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#South_Asian_Company': <ontotrees.node.Node at 0x7f2e98472828>,
#  'http://www.movieontology.org/2009/11/09/movieontology.owl#Colorinfo': <ontotrees.node.Node at 0x7f2e98472860>,
#  'http://dbpedia.org/ontology/Writer': <ontotrees.node.Node at 0x7f2e98472898>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Center_American_Company': <ontotrees.node.Node at 0x7f2e984728d0>,
#  'http://www.movieontology.org/2009/10/01/movieontology.owl#Western_Asia': <ontotrees.node.Node at 0x7f2e98472908>}

# %%
x = [('http://www.movieontology.org/2009/10/01/movieontology.owl#Genre', 'has_value', 'http://www.movieontology.org/2009/10/01/movieontology.owl#Fun')]

# %%
_get_entities(x)
# Out:
# ({},
#  {'http://www.movieontology.org/2009/10/01/movieontology.owl#Genre': False,
#   'http://www.movieontology.org/2009/10/01/movieontology.owl#Fun': True})
